# %%
pip install fastapi
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 8.7 MB/s  0:00:00m eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7/7 [fastapi]m6/7 [fastapi]]]types]
# ...
# Note: you may need to restart the kernel to use updated packages.
# Bad pipe message: %s [b' q=0.9, image/avif, image/webp, image/apng, */*; q=0.8, application/signed-exchange; v=b3; q=0.7\r\nHost: loc', b'host:38165\r\nUser-Agent: Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, lik']
# Bad pipe message: %s [b'Gecko) Chrome/142.0.0.0 Safari/537.36 Edg/142.0.0.0\r\nAccept-Encoding: gzip, deflate, br\r\nAccept-Lang']
# Bad pipe message: %s [b'ge: en-US, en; q=0.9, en-ZA; q=0.8\r\nCache-Control: max-age=0\r\nReferer: https://jubilant-succotash-vpq6wxp44vwcwpr9.g', b'hub.dev/\r\nX-Request-ID: 8a2c6b9de584789298f2160434f594d3\r\nX-Real-IP: 10.241.0.36\r\nX-Forwarded-Port: 443\r']
# Bad pipe message: %s [b'-Forwarde']
# ...

# %%
fastapi
